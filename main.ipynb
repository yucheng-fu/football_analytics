# %%
from statsbombpy import sb
import mplsoccer as mpl
from kloppy import metrica
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Colors

# %%
from matplotlib.colors import ListedColormap
def bulid_cmap(x, y):
    r,g,b = x
    r_, g_, b_ = y
    N = 256
    A = np.ones((N, 4))
    A[:, 0] = np.linspace(r, 1, N)
    A[:, 1] = np.linspace(g, 1, N)
    A[:, 2] = np.linspace(b, 1, N)
    cmp = ListedColormap(A)
    
    B = np.ones((N, 4))
    B[:, 0] = np.linspace(r_, 1, N)
    B[:, 1] = np.linspace(g_, 1, N)
    B[:, 2] = np.linspace(b_, 1, N)
    cmp_ = ListedColormap(B)
    
    newcolors = np.vstack((cmp(np.linspace(0, 1, 128)),
                            cmp_(np.linspace(1, 0, 128))))
    return ListedColormap(newcolors)
blue, red = (44,123,182), (215,25,28)
blue = [x/256 for x in blue]
red = [x/256 for x in red]
diverging = bulid_cmap(blue, red)
diverging_r = bulid_cmap(red, blue)

figsize = (9, 6)

# %% [markdown]
# Let's find the 2018 World cup

# %%
comps = sb.competitions()
comps.loc[(comps['competition_international'] == True)  & (comps['competition_gender'] == "male")].sort_values(by='season_name', ascending=False)
# Out:
#     competition_id  season_id   country_name        competition_name  \
# 21             223        282  South America            Copa America
# 68              55        282         Europe               UEFA Euro
# 2             1267        107         Africa  African Cup of Nations
# 29              43        106  International          FIFA World Cup
# 69              55         43         Europe               UEFA Euro
# 30              43          3  International          FIFA World Cup
# 31              43         55  International          FIFA World Cup
# 32              43         54  International          FIFA World Cup
# 33              43         51  International          FIFA World Cup
# 34              43        272  International          FIFA World Cup
# 35              43        270  International          FIFA World Cup
# 36              43        269  International          FIFA World Cup
#
#    competition_gender  competition_youth  competition_international  \
# 21               male              False                       True
# 68               male              False                       True
# 2                male              False                       True
# 29               male              False                       True
# 69               male              False                       True
# 30               male              False                       True
# 31               male              False                       True
# 32               male              False                       True
# 33               male              False                       True
# 34               male              False                       True
# 35               male              False                       True
# 36               male              False                       True
#
#    season_name               match_updated           match_updated_360  \
# 21        2024  2024-07-15T18:00:33.653673                        None
# 68        2024  2024-07-15T15:48:50.315500  2024-07-15T15:52:24.778809
# 2         2023  2024-06-13T07:51:02.452825                        None
# 29        2022  2024-05-15T10:23:32.854925  2024-06-11T11:30:50.462448
# 69        2020  2024-04-16T12:44:40.558402  2024-04-16T12:47:18.505110
# 30        2018  2024-06-12T07:38:19.345758     2021-06-13T16:17:31.694
# 31        1990  2023-06-28T10:58:20.137929     2021-06-12T16:17:31.694
# 32        1986  2023-12-26T22:34:04.263530     2021-06-13T16:17:31.694
# 33        1974  2024-02-13T02:52:29.582599     2021-06-13T16:17:31.694
# 34        1970  2024-02-13T14:23:06.735299                        None
# 35        1962  2023-06-26T10:38:00.323984                        None
# 36        1958  2024-02-13T14:22:08.222297                        None
#
#            match_available_360             match_available
# 21                        None  2024-07-15T18:00:33.653673
# 68  2024-07-15T15:52:24.778809  2024-07-15T15:48:50.315500
# 2                         None  2024-06-13T07:51:02.452825
# 29  2024-06-11T11:30:50.462448  2024-05-15T10:23:32.854925
# 69  2024-04-16T12:47:18.505110  2024-04-16T12:44:40.558402
# 30                        None  2024-06-12T07:38:19.345758
# 31                        None  2023-06-28T10:58:20.137929
# 32                        None  2023-12-26T22:34:04.263530
# 33                        None  2024-02-13T02:52:29.582599
# 34                        None  2024-02-13T14:23:06.735299
# 35                        None  2023-06-26T10:38:00.323984
# 36                        None  2024-02-13T14:22:08.222297

# %% [markdown]
# Let's have a look at France's matches.

# %%
matches = sb.matches(competition_id=43, season_id=3).sort_values('match_date', ascending=False)
france_matches = matches.loc[(matches['home_team'] == 'France') | (matches['away_team'] == 'France')]
france_matches
# Out:
#     match_id  match_date      kick_off                     competition season  \
# 39      8658  2018-07-15  17:00:00.000  International - FIFA World Cup   2018
# 57      8655  2018-07-10  20:00:00.000  International - FIFA World Cup   2018
# 38      8649  2018-07-06  16:00:00.000  International - FIFA World Cup   2018
# 21      7580  2018-06-30  16:00:00.000  International - FIFA World Cup   2018
# 61      7563  2018-06-26  16:00:00.000  International - FIFA World Cup   2018
# 14      7546  2018-06-21  17:00:00.000  International - FIFA World Cup   2018
# 31      7530  2018-06-16  12:00:00.000  International - FIFA World Cup   2018
#
#    home_team  away_team  home_score  away_score match_status  ...  \
# 39    France    Croatia           4           2    available  ...
# 57    France    Belgium           1           0    available  ...
# 38   Uruguay     France           0           2    available  ...
# 21    France  Argentina           4           3    available  ...
# 61   Denmark     France           0           0    available  ...
# 14    France       Peru           1           0    available  ...
# 31    France  Australia           2           1    available  ...
#
#            last_updated_360 match_week competition_stage  \
# 39  2021-06-13T16:17:31.694          7             Final
# 57  2021-06-13T16:17:31.694          6       Semi-finals
# 38  2021-06-13T16:17:31.694          5    Quarter-finals
# 21  2021-06-13T16:17:31.694          4       Round of 16
# 61  2021-06-13T16:17:31.694          3       Group Stage
# 14  2021-06-13T16:17:31.694          2       Group Stage
# 31  2021-06-13T16:17:31.694          1       Group Stage
#
#                                        stadium                      referee  \
# 39                            Stadion Luzhniki         Néstor Fabián Pitana
# 57                    Saint-Petersburg Stadium                 Andrés Cunha
# 38  Stadion Nizhny Novgorod (Nizhniy Novgorod)         Néstor Fabián Pitana
# 21                               Ak Bars Arena              Alireza Faghani
# 61                            Stadion Luzhniki                 Sandro Ricci
# 14                        \tEkaterinburg Arena  Mohamed Abdulla Hassan Mohd
# 31                               Ak Bars Arena                 Andrés Cunha
#
#                      home_managers                 away_managers data_version  \
# 39                Didier Deschamps                  Zlatko Dalić        1.0.2
# 57                Didier Deschamps     Roberto Martínez Montoliú        1.0.2
# 38  Óscar Washington Tabárez Silva              Didier Deschamps        1.0.2
# 21                Didier Deschamps      Jorge Luis Sampaoli Moya        1.0.2
# 61            Åge Fridtjof Hareide              Didier Deschamps        1.0.2
# 14                Didier Deschamps  Ricardo Alberto Gareca Nardi        1.0.2
# 31                Didier Deschamps         Lambertus van Marwijk        1.0.2
#
#    shot_fidelity_version xy_fidelity_version
# 39                  None                None
# 57                  None                None
# 38                  None                None
# 21                  None                None
# 61                  None                None
# 14                  None                None
# 31                  None                None
#
# [7 rows x 22 columns]

# %% [markdown]
# 4-3 in the Round of 16, that was a good game.

# %%
match_id = france_matches.loc[france_matches['competition_stage'] == 'Round of 16'].match_id.item()

events = sb.events(match_id = match_id)

# %%
passes = events[(events['type'] == "Pass") & 
                (events['player_id'] == 5484)]

shots = events[(events['type'] == "Shot") &
               (events['player_id'] == 5476)]

# %%
shots['shot_statsbomb_xg']
# Out:
# 3480    0.02415
# Name: shot_statsbomb_xg, dtype: float64

# %%
pass_coordinates = passes[['location', 'pass_end_location']]
shot_coordinates = shots[['location', 'shot_end_location']]

# %%
x1_pass, y1_pass = np.array(pass_coordinates['location'].tolist()).T
x2_pass, y2_pass = np.array(pass_coordinates['pass_end_location'].tolist()).T

# %%
x1_shot, y1_shot = np.array(shot_coordinates['location'].tolist()).T
x2_shot, y2_shot, outcome = np.array(shot_coordinates['shot_end_location'].tolist()).T

# %%
pitch = mpl.Pitch()
fig, ax = pitch.draw(figsize=figsize)

p = pitch.arrows(x1_pass, y1_pass, x2_pass, y2_pass, alpha=0.4, color=blue,
                 headaxislength=3, headlength=3, headwidth=4, width=2, ax=ax)
p = pitch.arrows(x1_shot, y1_shot, x2_shot, y2_shot, alpha=0.4, color=red,
                 headaxislength=3, headlength=3, headwidth=4, width=2, ax=ax)

# %% [markdown]
# # Implementing the expected threat (xT) algorithm for a specific match

# %%
import pandas as pd

# %%
all_match_ids = matches.match_id.to_list()[:3]

# %%
all_events = pd.DataFrame()

for match_id in all_match_ids:
    match_events = sb.events(match_id=match_id)
    all_events = pd.concat([all_events, match_events], ignore_index=True)

all_events
# Out:
#       ball_receipt_outcome ball_recovery_recovery_failure block_deflection  \
# 0                      NaN                            NaN              NaN
# 1                      NaN                            NaN              NaN
# 2                      NaN                            NaN              NaN
# 3                      NaN                            NaN              NaN
# 4                      NaN                            NaN              NaN
# ...                    ...                            ...              ...
# 11564                  NaN                            NaN              NaN
# 11565                  NaN                            NaN              NaN
# 11566                  NaN                            NaN              NaN
# 11567                  NaN                            NaN              NaN
# 11568                  NaN                            NaN              NaN
#
#       carry_end_location clearance_aerial_won counterpress dribble_outcome  \
# 0                    NaN                  NaN          NaN             NaN
# 1                    NaN                  NaN          NaN             NaN
# 2                    NaN                  NaN          NaN             NaN
# 3                    NaN                  NaN          NaN             NaN
# 4                    NaN                  NaN          NaN             NaN
# ...                  ...                  ...          ...             ...
# 11564                NaN                  NaN          NaN             NaN
# 11565                NaN                  NaN          NaN             NaN
# 11566                NaN                  NaN          NaN             NaN
# 11567                NaN                  NaN          NaN             NaN
# 11568                NaN                  NaN          NaN             NaN
#
#       dribble_overrun duel_outcome duel_type  ...               type  \
# 0                 NaN          NaN       NaN  ...        Starting XI
# 1                 NaN          NaN       NaN  ...        Starting XI
# 2                 NaN          NaN       NaN  ...         Half Start
# 3                 NaN          NaN       NaN  ...         Half Start
# 4                 NaN          NaN       NaN  ...         Half Start
# ...               ...          ...       ...  ...                ...
# 11564             NaN          NaN       NaN  ...             Shield
# 11565             NaN          NaN       NaN  ...     Tactical Shift
# 11566             NaN          NaN       NaN  ...         Camera off
# 11567             NaN          NaN       NaN  ...  Referee Ball-Drop
# 11568             NaN          NaN       NaN  ...  Referee Ball-Drop
#
#       under_pressure 50_50 bad_behaviour_card ball_recovery_offensive  \
# 0                NaN   NaN                NaN                     NaN
# 1                NaN   NaN                NaN                     NaN
# 2                NaN   NaN                NaN                     NaN
# 3                NaN   NaN                NaN                     NaN
# 4                NaN   NaN                NaN                     NaN
# ...              ...   ...                ...                     ...
# 11564            NaN   NaN                NaN                     NaN
# 11565            NaN   NaN                NaN                     NaN
# 11566            NaN   NaN                NaN                     NaN
# 11567            NaN   NaN                NaN                     NaN
# 11568            NaN   NaN                NaN                     NaN
#
#       block_save_block foul_committed_offensive shot_one_on_one shot_redirect  \
# 0                  NaN                      NaN             NaN           NaN
# 1                  NaN                      NaN             NaN           NaN
# 2                  NaN                      NaN             NaN           NaN
# 3                  NaN                      NaN             NaN           NaN
# 4                  NaN                      NaN             NaN           NaN
# ...                ...                      ...             ...           ...
# 11564              NaN                      NaN             NaN           NaN
# 11565              NaN                      NaN             NaN           NaN
# 11566              NaN                      NaN             NaN           NaN
# 11567              NaN                      NaN             NaN           NaN
# 11568              NaN                      NaN             NaN           NaN
#
#       dribble_nutmeg
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# ...              ...
# 11564            NaN
# 11565            NaN
# 11566            NaN
# 11567            NaN
# 11568            NaN
#
# [11569 rows x 85 columns]

# %%
GRID_X, GRID_Y = 16, 12
pitch_x, pitch_y = 120, 80  # Standard pitch dimensions in meters
x_bins = np.linspace(0, pitch_x, GRID_X + 1)
y_bins = np.linspace(0, pitch_y, GRID_Y + 1)

# %%
def get_grid_cell(x, y):
    x_idx = np.digitize(x, x_bins) - 1
    y_idx = np.digitize(y, y_bins) - 1
    return x_idx, y_idx

# %%
transition_matrix = np.zeros((GRID_X, GRID_Y, GRID_X, GRID_Y))

# %%
# Extract relevant passes and carries
passes = all_events[all_events['type'] == 'Pass']
carries = all_events[all_events['type'] == 'Carry']
shots = all_events[all_events['type'] == 'Shot']

# %%
T = np.zeros((GRID_X, GRID_Y, GRID_X, GRID_Y))
S = np.zeros((GRID_X, GRID_Y))  # shot counts
M = np.zeros((GRID_X, GRID_Y))  # move counts

# %%
# Process passes and carries
for _, row in pd.concat([passes, carries]).iterrows():
    try:
        start_x, start_y = row['location']
        end = row.get('pass_end_location') if isinstance(row.get('pass_end_location'), list) else row.get('carry_end_location')
        if not isinstance(end, list):
            continue
        end_x, end_y = end
        sx, sy = get_grid_cell(start_x, start_y)
        ex, ey = get_grid_cell(end_x, end_y)
        if 0 <= sx < GRID_X and 0 <= sy < GRID_Y and 0 <= ex < GRID_X and 0 <= ey < GRID_Y:
            T[sx, sy, ex, ey] += 1
            M[sx, sy] += 1
    except:
        continue

# %%
# Process shots
for _, row in shots.iterrows():
    try:
        x, y = row['location']
        sx, sy = get_grid_cell(x, y)
        S[sx, sy] += row['shot_statsbomb_xg']
    except:
        continue

# %%
# Normalize transition probabilities
P_move = np.divide(M, M + S, out=np.zeros_like(M), where=(M + S) != 0)
P_shot = np.divide(S, M + S, out=np.zeros_like(S), where=(M + S) != 0)
P_trans = np.divide(T, T.sum(axis=(2,3), keepdims=True), out=np.zeros_like(T), where=T.sum(axis=(2,3), keepdims=True)!=0)

# %%
# --- Iterative xT calculation with plotting ---
xT = np.copy(S)
for iteration in range(20):  # Show first 20 iterations
    new_xT = np.copy(xT)
    for i in range(GRID_X):
        for j in range(GRID_Y):
            future_threat = np.sum(P_trans[i, j] * xT)
            new_xT[i, j] = P_shot[i, j] * S[i, j] + P_move[i, j] * future_threat

    # Plotting the pitch xT after this iteration
    plt.figure(figsize=(10, 6))
    plt.imshow(new_xT.T, origin='lower', cmap='plasma', extent=[0, pitch_x, 0, pitch_y])
    plt.title(f"xT Map - Iteration {iteration+1}")
    plt.colorbar(label="xT Value")
    plt.xlabel("Pitch X")
    plt.ylabel("Pitch Y")
    plt.show()

    if np.sum(np.abs(new_xT - xT)) < 1e-6:
        print(f"Converged at iteration {iteration+1}")
        break
    xT = new_xT
